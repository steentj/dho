# %% [markdown]
# ## Aktivitetsoversigt opsætning af søgedatabase
# 1. Installer nødvendige pakker. Skal kun gøres en gang.
# 2. Opret tabeller i database angivet i environment

# %% [markdown]
# ### Installer nødvendige biblioteker
# Installerer Python pakker. Skal kun gøres en gang.
#
# Husk også at sætte environment variable op. De er:
# - Database navn (POSTGRES_DB)
# - Database bruger (POSTGRES_USER)
# - Database pasord (POSTGRES_PASSWORD)

# %%
### Installer pakker
# %pip install psycopg2-binary
# %pip install python_dotenv

# %% [markdown]
# ### Opret tabeller til chunket tekst i Postgresql
# 3 tabeller:
# 1. Books: Metaoplysninger om PDF url, bogtitel og antal sider.
# 2. Pages: Råt udtræk af siderne i alle bøger
# 3. Chunks: Vektor tabellen med tekststykker og tilhørende embeddings

# %%
import psycopg2
from pgvector.psycopg2 import register_vector
from dotenv import load_dotenv
import os

load_dotenv()
database = os.getenv("POSTGRES_DB", None)
db_user = os.getenv("POSTGRES_USER", None)
db_password = os.getenv("POSTGRES_PASSWORD", None)

cn = psycopg2.connect(
    host="localhost",
    database=database,
    user=db_user,
    password=db_password,
)

cur = cn.cursor()

cur.execute("CREATE EXTENSION IF NOT EXISTS vector")
register_vector(cn)
# cur.execute("DROP TABLE IF EXISTS chunks")
# cur.execute("DROP TABLE IF EXISTS pages")
# cur.execute("DROP TABLE IF EXISTS books")
# cur.execute("DROP TABLE IF EXISTS chunks")

cur.execute("CREATE TABLE IF NOT EXISTS chunks_udentitel \
            (id BIGSERIAL PRIMARY KEY, \
             book_id integer NOT NULL REFERENCES books ON DELETE RESTRICT, \
             sidenr int NOT NULL, \
             chunk text NOT NULL, \
             embedding VECTOR(1536))")

# cur.execute("CREATE TABLE IF NOT EXISTS books \
#             (id SERIAL PRIMARY KEY, \
#              pdf_navn text NOT NULL,  \
#              titel text NOT NULL,  \
#              forfatter text,  \
#              antal_sider int NOT NULL)")

# cur.execute("CREATE TABLE IF NOT EXISTS pages \
#             (id SERIAL PRIMARY KEY, \
#              book_id integer NOT NULL REFERENCES books ON DELETE RESTRICT, \
#              sidenr int NOT NULL, \
#              antal_ord int NOT NULL, \
#              tekst text NOT NULL)")


# cur.execute("CREATE TABLE IF NOT EXISTS chunks \
#             (id BIGSERIAL PRIMARY KEY, \
#              book_id integer NOT NULL REFERENCES books ON DELETE RESTRICT, \
#              sidenr int NOT NULL, \
#              chunk text NOT NULL, \
#              embedding VECTOR(1536))")

# cur.execute("CREATE TABLE IF NOT EXISTS chunks_large \
#             (id BIGSERIAL PRIMARY KEY, \
#              book_id integer NOT NULL REFERENCES books ON DELETE RESTRICT, \
#              sidenr int NOT NULL, \
#              chunk text NOT NULL, \
#              embedding VECTOR(1536))")


cn.commit()

cur.close()
cn.close()

# %% [markdown]
# ### Tøm tabeller efter behov
# Hjælpe rutine til at tømme tabellerne

# %%
import psycopg2
from dotenv import load_dotenv
import os

load_dotenv()
database = os.getenv("POSTGRES_DB", None)
db_user = os.getenv("POSTGRES_USER", None)
db_password = os.getenv("POSTGRES_PASSWORD", None)

cn = psycopg2.connect(
    host="localhost",
    database=database,
    user=db_user,
    password=db_password
)

cur = cn.cursor()

cur.execute("DELETE FROM chunks")
# cur.execute("DELETE FROM test_chunks")
# cur.execute("DELETE FROM test_spm")
# cur.execute("DELETE FROM pages")
# cur.execute("DELETE FROM books")

cn.commit()

cur.close()
cn.close()

# %% [markdown]
# ## Indlæs bøger i lokale tabeller
# Books og Chunks tabellerne fyldes af det egentlige oprettelsesprogram (læs_pdf_filer.py). Denne rutine indlæser teksten i Pages, så det bliver nemmere at forstå chunking og embedding problemer.

# %%
import psycopg2
import requests
import pymupdf
from dotenv import load_dotenv
import os

load_dotenv()
database = os.getenv("POSTGRES_DB", None)
db_user = os.getenv("POSTGRES_USER", None)
db_password = os.getenv("POSTGRES_PASSWORD", None)

def save_book(book) -> None:
    cn = psycopg2.connect(
    host="localhost",
    database=database,
    user=db_user,
    password=db_password
    )

    cur = cn.cursor()

    
    cur.execute(
        "INSERT INTO books(pdf_navn, titel, forfatter, antal_sider) "
        + "VALUES (%s, %s, %s, %s) RETURNING id",
        (book["pdf-url"], book["titel"], book["forfatter"], book["antal_sider"]),
    )

    book_id = cur.fetchone()[0]
 
    print(f"{book["pdf-url"]} -> book_id: {book_id} {book["titel"]}")

    for page in book["sider"]:
        cur.execute("INSERT INTO pages(book_id, sidenr, antal_ord, tekst) VALUES (%s, %s, %s, %s)",
                    (book_id, page["side"], page["antalord"], page["tekst"]))
        
    cn.commit()
    cur.close()
    cn.close()


with open("samlet_input.txt", "rb") as pdfer:
    for url in filter(lambda x: not x[0] == "#", pdfer):
        url = url.strip()

        try:
            r = requests.get(url)
            r.raise_for_status()
        except requests.exceptions.HTTPError as e:
            print(f"HTTP-fejl opstod: {e}")
            continue
        except requests.exceptions.ConnectionError as e:
            print(f"Forbindelsesfejl opstod: {e}")
            continue
        except requests.exceptions.Timeout as e:
            print(f"Timeout-fejl opstod: {e}")
            continue
        except requests.exceptions.RequestException as e:
            print(f"En ukendt fejl opstod: {e}")
            continue

        pdf = pymupdf.open("pdf", r.content)

        metadata = pdf.metadata
        book = {
            "pdf-url": str(url.decode("utf-8")),  # pdf_url,
            "titel": metadata["title"],
            "forfatter": metadata["author"],
            "antal_sider": len(pdf),
            "sider": [],
        }
        
        for i in range(1, len(pdf) - 1) :
            text = pdf[i].get_text("text")
            antalord = len(text.split())
            page = { "side": i, "antalord": antalord, "tekst": text }
            book["sider"].append(page)

        pdf.close()

        save_book(book)
# Out:
# https://slaegtsbibliotek.dk/2024/904286.pdf -> book_id: 381 Anetavle for Inger Grene
# https://slaegtsbibliotek.dk/2024/904285.pdf -> book_id: 382 Anetavle for Anna Krogh
# https://slaegtsbibliotek.dk/2024/904288.pdf -> book_id: 383 Falsleds Kongerække
# https://slaegtsbibliotek.dk/2024/904289.pdf -> book_id: 384 Allan Tønnesens fædrene slægt
# https://slaegtsbibliotek.dk/2024/904291.pdf -> book_id: 385 Slægtsbog om familien Jens Jensen Landgreen
# https://slaegtsbibliotek.dk/2024/904293.pdf -> book_id: 386 Slægten Rolsted 250 år, april 2010
# https://slaegtsbibliotek.dk/2024/904295.pdf -> book_id: 387 Niels Frederik Christiann Roilsteds breve 1846-1854
# https://slaegtsbibliotek.dk/2024/904298.pdf -> book_id: 388 Anetavle for Eva Sørensen
# https://slaegtsbibliotek.dk/2024/904319.pdf -> book_id: 389 Andreas Sørensen Torrild
# https://slaegtsbibliotek.dk/2024/904321.pdf -> book_id: 390 Aner til Niels Christian Christensen 1842 i Albæk-1921 i Hørby
# https://slaegtsbibliotek.dk/2024/904323.pdf -> book_id: 391 Minder fra Barfredshøj - Tillæg
# https://slaegtsbibliotek.dk/2024/904325.pdf -> book_id: 392 Anetavle for Niels Kristoffersen
# https://slaegtsbibliotek.dk/2024/904327.pdf -> book_id: 393 Anetavle for Niels Erhardtsen
# https://slaegtsbibliotek.dk/2024/904330.pdf -> book_id: 394 Aner til Christen Sørensen 1854 i Hagested-1739 i Fr.berg
# https://slaegtsbibliotek.dk/2024/904332.pdf -> book_id: 395 København jævnførelsesregistre kumuleret
# https://slaegtsbibliotek.dk/2024/904356.pdf -> book_id: 396 Anetavle for ToveMalzer
# HTTP-fejl opstod: 404 Client Error: Not Found for url: https://slaegtsbibliotek.dk/2024/904381.pdf
# https://slaegtsbibliotek.dk/2024/904404.pdf -> book_id: 397 Anetavle for Anders Bondo
# https://slaegtsbibliotek.dk/2024/904405.pdf -> book_id: 398 Anetavle for Hanne Jensbo
# https://slaegtsbibliotek.dk/2024/904406.pdf -> book_id: 399 Anetavle for Henrik Dam Kristensen
# https://slaegtsbibliotek.dk/2024/942133.pdf -> book_id: 400 Flugten over Øresund
# https://slaegtsbibliotek.dk/922714.pdf -> book_id: 401 Gør jer pligt - gør jert værk
# https://slaegtsbibliotek.dk/927311.pdf -> book_id: 402 Jeg hader støvletramp. En ung piges dagbog 1940-45
# https://slaegtsbibliotek.dk/924732.pdf -> book_id: 403 Flåden den 29. august 1943
# https://slaegtsbibliotek.dk/2024/932467.pdf -> book_id: 404 5te kolonne.
# https://slaegtsbibliotek.dk/2024/941387.pdf -> book_id: 405 Da Danmark kaldte - Bogen om modstandsbevægelsen
# https://slaegtsbibliotek.dk/2023/932256.pdf -> book_id: 406 20-årsdagen for Frøslevlejrens befrielse
# https://slaegtsbibliotek.dk/2024/942226.pdf -> book_id: 407 9. april, skildret i Breve fra danske Soldater
# https://slaegtsbibliotek.dk/931216.pdf -> book_id: 408 Besættelsestiden
# https://slaegtsbibliotek.dk/924389.pdf -> book_id: 409 BOPA mindebogen
# https://dis-danmark.dk/bibliotek/910416.pdf -> book_id: 410  Chr. U. og hans venner
# https://slaegtsbibliotek.dk/934076.pdf -> book_id: 411 Danmark under Besættelsen, bind 1
# https://slaegtsbibliotek.dk/934077.pdf -> book_id: 412 Danmark under Besættelsen, bind 3
# https://slaegtsbibliotek.dk/2023/932362.pdf -> book_id: 413 Danmarks frihedskamp bnd 1
# https://slaegtsbibliotek.dk/2023/932364.pdf -> book_id: 414  Danmarks frihedskamp bnd 2
# https://slaegtsbibliotek.dk/932051.pdf -> book_id: 415 Danmarks militære Besættelse.
# https://slaegtsbibliotek.dk/2024/942132.pdf -> book_id: 416 Dansk Politi bag Pigtraad
# https://slaegtsbibliotek.dk/935204.pdf -> book_id: 417 Danske i tyske Koncentrationslejre
# https://slaegtsbibliotek.dk/934831.pdf -> book_id: 418 De faldt for Fædrelandet
# https://dis-danmark.dk/bibliotek/923198.pdf -> book_id: 419 De så det ske under besættelsen
# https://slaegtsbibliotek.dk/2023/932376.pdf -> book_id: 420 De sorte tog.
# https://slaegtsbibliotek.dk/2023/938412.pdf -> book_id: 421 Den Danske Brigade i Sverige
# https://dis-danmark.dk/bibliotek/911749.pdf -> book_id: 422 Den tyske kapitulation 4. maj 1945
# https://slaegtsbibliotek.dk/2024/942166.pdf -> book_id: 423 Det er nødvendigt at sejle - Nordsø fiskeriet under 2. verdenskrig
# https://slaegtsbibliotek.dk/932144.pdf -> book_id: 424 Dødsliste over danske sømænd under 2. verdenskrig
# https://dis-danmark.dk/bibliotek/911834.pdf -> book_id: 425 Dr. Werner Best Kalendernotater 1943-1944, Bind 1
# https://dis-danmark.dk/bibliotek/911838.pdf -> book_id: 426 Dr. Werner Best kalendernotater 1943-1944, Bind 2
# https://dis-danmark.dk/bibliotek/911839.pdf -> book_id: 427 Dr. Werner Best kalendernotater 1943-1944, Bind 3
# https://slaegtsbibliotek.dk/928501.pdf -> book_id: 428 Efterlysningsliste til brug for Feltpolitidetachementet
# https://slaegtsbibliotek.dk/935127.pdf -> book_id: 429 Faldne i Danmarks frihedskamp 1940-45
# https://slaegtsbibliotek.dk/2023/932245.pdf -> book_id: 430 Før Revisionen  Tre artikler om Rostockmødet
# https://slaegtsbibliotek.dk/929576.pdf -> book_id: 431 Frie Danske i London 1940-45
# https://slaegtsbibliotek.dk/929482.pdf -> book_id: 432 Kampen om Amalienborg 19. september 1944
# https://slaegtsbibliotek.dk/2023/935454.pdf -> book_id: 433 Mindebogen
# https://slaegtsbibliotek.dk/935149.pdf -> book_id: 434 Nymindegablejren 1940 - 1945
# https://slaegtsbibliotek.dk/931101.pdf -> book_id: 435 REGIMENT NORDLAND I DIVISION WIKING
# https://slaegtsbibliotek.dk/2023/938365.pdf -> book_id: 436 Rettelser til Bovrup-bogen!
# http://dis-danmark.dk/bibliotek/907093.pdf -> book_id: 437 Samling af illegale blade
# https://slaegtsbibliotek.dk/2023/937303.pdf -> book_id: 438 Dansk Politi under tysk besættelse 1940-1945
# https://slaegtsbibliotek.dk/931423.pdf -> book_id: 439 Våben i Klitterne
# https://slaegtsbibliotek.dk/928736.pdf -> book_id: 440 En mur har to sider
# https://slaegtsbibliotek.dk/932113.pdf -> book_id: 441 Ingen tænder et Lys
# https://slaegtsbibliotek.dk/929483.pdf -> book_id: 442 Monica Wichfeld
# https://slaegtsbibliotek.dk/2023/935474.pdf -> book_id: 443 Under 2. verdenskrig
# https://slaegtsbibliotek.dk/932061.pdf -> book_id: 444 Den danske hær VI 9. april 1940
# https://slaegtsbibliotek.dk/927726.pdf -> book_id: 445 Besættelsestiden 1940-45 på egnen omkring Slagslunde-Ganløse og Stenløse-Veksø
# https://slaegtsbibliotek.dk/928513.pdf -> book_id: 446 Klunketid og krigsår
